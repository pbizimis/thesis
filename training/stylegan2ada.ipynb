# %%
# !nvidia-smi
# Out:
# Wed Mar 31 07:53:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3 torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 204kB 15.4MB/s
# ...
#      |████████████████████████████████| 112kB 12.8MB/s
# ...
#      |████████████████████████████████| 26.9MB 1.4MB/s
# ...
#      |███████████████████████         | 834.1MB 1.2MB/s eta 0:04:24tcmalloc: large alloc 1147494400 bytes == 0x55cb183b6000 @  0x7f1000af0615 0x55cadfd8606c 0x55cadfe65eba 0x55cadfd88e8d 0x55cadfe7a99d 0x55cadfdfcfe9 0x55cadfdf7b0e 0x55cadfd8a77a 0x55cadfdfce50 0x55cadfdf7b0e 0x55cadfd8a77a 0x55cadfdf986a 0x55cadfe7b7c6 0x55cadfdf8ee2 0x55cadfe7b7c6 0x55cadfdf8ee2 0x55cadfe7b7c6 0x55cadfdf8ee2 0x55cadfe7b7c6 0x55cadfefd431 0x55cadfe5e049 0x55cadfdc8c84 0x55cadfd898e9 0x55cadfdfdade 0x55cadfd8a69a 0x55cadfdf8a45 0x55cadfdf7e0d 0x55cadfd8a77a 0x55cadfdf8a45 0x55cadfd8a69a 0x55cadfdf8a45
# ...

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 1.12 MiB | 3.37 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd stylegan2-ada-pytorch/
# Out:
# [Errno 2] No such file or directory: 'stylegan2-ada-pytorch/'
# /content/stylegan2-ada-pytorch

# %%
dataset_name = "set_128x128"
image_path = f"/content/drive/MyDrive/Training/{dataset_name}"
log_path = "/content/drive/MyDrive/Training/training_sets_gauto"

# %%
# !python dataset_tool.py --source /content/drive/MyDrive/Training/good_images --dest /content/drive/MyDrive/Training/{dataset_name} --width=256 --height=256

# %%
# !python train.py --outdir={log_path} --data={image_path} --gpus=1 --resume=/content/drive/MyDrive/Training/training_sets_gauto/00007-set_128x128-auto1-resumecustom/network-snapshot-000400.pkl
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/Training/set_128x128",
#     "use_labels": false,
#     "max_size": 31165,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
# ...
